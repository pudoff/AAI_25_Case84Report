# %% [markdown]
# Первый вариант - алгоритм градиентного бустинга CatBoost, автоматический подбор гиперпараметров и регуляризация с использованием Optuna и кросс-валидацией, с масштабированием RobustScaler, без категориального признака 'Sector'.

# %%
import polars as pl
import numpy as np
import pandas as pd
import pyarrow

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score, TimeSeriesSplit
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error
from sklearn.model_selection import train_test_split

# %%
# Загружаем датасет с данными
data = pl.read_csv('financials.csv')
data.head()
# Out:
# shape: (5, 17)
# ┌────────┬─────────────┬─────────────┬────────┬───┬─────────────┬──────────┬───────────┬───────────┐
# │ Symbol ┆ Name        ┆ Sector      ┆ Price  ┆ … ┆ SEC Filings ┆ Earnings ┆ Sales     ┆ Book      │
# │ ---    ┆ ---         ┆ ---         ┆ ---    ┆   ┆ ---         ┆ ---      ┆ ---       ┆ ---       │
# │ str    ┆ str         ┆ str         ┆ f64    ┆   ┆ str         ┆ f64      ┆ f64       ┆ f64       │
# ╞════════╪═════════════╪═════════════╪════════╪═══╪═════════════╪══════════╪═══════════╪═══════════╡
# │ MMM    ┆ 3M Company  ┆ Industrials ┆ 222.89 ┆ … ┆ http://www. ┆ 9.168655 ┆ 50.769079 ┆ 19.655203 │
# │        ┆             ┆             ┆        ┆   ┆ sec.gov/cgi ┆          ┆           ┆           │
# │        ┆             ┆             ┆        ┆   ┆ -bin/bro…   ┆          ┆           ┆           │
# │ AOS    ┆ A.O. Smith  ┆ Industrials ┆ 60.24  ┆ … ┆ http://www. ┆ 2.170029 ┆ 16.848075 ┆ 9.486614  │
# │        ┆ Corp        ┆             ┆        ┆   ┆ sec.gov/cgi ┆          ┆           ┆           │
# │        ┆             ┆             ┆        ┆   ┆ -bin/bro…   ┆          ┆           ┆           │
# │ ABT    ┆ Abbott Labo ┆ Health Care ┆ 56.27  ┆ … ┆ http://www. ┆ 2.499778 ┆ 15.043522 ┆ 17.639498 │
# │        ┆ ratories    ┆             ┆        ┆   ┆ sec.gov/cgi ┆          ┆           ┆           │
# │        ┆             ┆             ┆        ┆   ┆ -bin/bro…   ┆          ┆           ┆           │
# │ ABBV   ┆ AbbVie Inc. ┆ Health Care ┆ 108.48 ┆ … ┆ http://www. ┆ 5.588872 ┆ 17.242116 ┆ 4.149962  │
# │        ┆             ┆             ┆        ┆   ┆ sec.gov/cgi ┆          ┆           ┆           │
# │        ┆             ┆             ┆        ┆   ┆ -bin/bro…   ┆          ┆           ┆           │
# │ ACN    ┆ Accenture   ┆ Information ┆ 150.51 ┆ … ┆ http://www. ┆ 5.909305 ┆ 57.796942 ┆ 14.172316 │
# │        ┆ plc         ┆ Technology  ┆        ┆   ┆ sec.gov/cgi ┆          ┆           ┆           │
# │        ┆             ┆             ┆        ┆   ┆ -bin/bro…   ┆          ┆           ┆           │
# └────────┴─────────────┴─────────────┴────────┴───┴─────────────┴──────────┴───────────┴───────────┘

# %%
# Выбираем нужные столбцы 
df_polars = data.select(['Sector', 'Dividend Yield', 'Earnings/Share', '52 Week Low', '52 Week High', 'Market Cap', 'EBITDA', 'Earnings', 'Sales', 'Book'])

# %%
# Целевая переменная
y = df_polars['Market Cap']

# Признаки (все остальные столбцы, кроме целевой)
X = df_polars.select(['Dividend Yield', 'Earnings/Share', '52 Week Low', '52 Week High', 'EBITDA', 'Earnings', 'Sales', 'Book'])

# %%
# Конвертируем Polars DataFrame в Pandas DataFrame
y = y.to_pandas()
X = X.to_pandas()

# %%
# Разделяем на train/test (последние 20% для теста)
split_idx = int(len(X) * 0.8)
X_train, X_test = X[:split_idx], X[split_idx:]
y_train, y_test = y[:split_idx], y[split_idx:]

# %%
# Создадим объект класса RobustScaler
scaler = RobustScaler()
scaler
# Out:
# RobustScaler()

# %%
# Масштабируем признаки обучающей выборки
X_train_scaled = scaler.fit_transform(X_train)

# %%
# Преобразуем тестовые данные с использованием среднего и СКО, рассчитанных на обучающей выборке, так тестовые данные не повляют на обучение модели, и мы избежим утечки данных
X_test_scaled = scaler.transform(X_test)

# %%
import optuna

# %%
# Импортируем необходимые библиотеки и произведем базовые настройки
from catboost import CatBoostRegressor
from catboost import Pool, cv, sum_models

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, root_mean_squared_error, mean_absolute_error, r2_score  # Метрики ошибок

# %%
# Функция для objective (целевой метрики) в Optuna
def objective(trial):
    # Подбор гиперпараметров через trial
    params = {
        'iterations': trial.suggest_int('iterations', 500, 1500, step=100),             # Количество деревьев
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),     # Скорость обучения
        'depth': trial.suggest_int('depth', 4, 8),                                      # Глубина деревьев
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1e-2, 10.0, log=True),        # L2 регуляризация
        'random_seed': 42,                                                              # Фиксированное значение random
        'verbose': 0                                                                   # Частота вывода
        # 'cat_features': cat_features                                                # Указываем категориальные признаки прямо в модели
    }
    
    # Создаём модель с текущими параметрами
    regressor = CatBoostRegressor(**params)
    
    # Кросс‑валидация (5 фолдов)
    cv_strategy = KFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(
        regressor, X_train_scaled, y_train,
        cv=cv_strategy,
        scoring='r2'
    ) 

    # Возвращаем среднее значение метрики (Optuna максимизирует objective)
    return np.mean(scores)

# %%
# Создание исследования Optuna
study = optuna.create_study(
    direction='maximize',  # Максимизируем R2
    sampler=optuna.samplers.TPESampler(seed=42)
)
# Out:
# [I 2025-12-13 15:23:05,714] A new study created in memory with name: no-name-2d983fe7-4262-4e4e-84d9-e878a7326cab

# %%
# Запуск оптимизации (100 итераций)
study.optimize(objective, n_trials=100, show_progress_bar=True)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-12-13 15:43:18,840] Trial 59 finished with value: 0.5491050969204578 and parameters: {'iterations': 1000, 'learning_rate': 0.03973245445485517, 'depth': 4, 'l2_leaf_reg': 0.3559236704160857}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:43:29,395] Trial 60 finished with value: 0.5641376691364849 and parameters: {'iterations': 800, 'learning_rate': 0.10262953475914954, 'depth': 6, 'l2_leaf_reg': 0.1277653473006057}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:43:44,290] Trial 61 finished with value: 0.5606818473339479 and parameters: {'iterations': 1200, 'learning_rate': 0.06447150117220939, 'depth': 6, 'l2_leaf_reg': 0.2475096199685566}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:43:57,388] Trial 62 finished with value: 0.545903859902019 and parameters: {'iterations': 1100, 'learning_rate': 0.08865540296339046, 'depth': 6, 'l2_leaf_reg': 0.176645688809692}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:44:08,428] Trial 63 finished with value: 0.5644567551632299 and parameters: {'iterations': 1300, 'learning_rate': 0.11775354745026988, 'depth': 5, 'l2_leaf_reg': 0.31815469860800516}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:44:20,307] Trial 64 finished with value: 0.553341460654502 and parameters: {'iterations': 1000, 'learning_rate': 0.07399890540694683, 'depth': 6, 'l2_leaf_reg': 0.10531820241553551}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:44:38,572] Trial 65 finished with value: 0.5428222846670209 and parameters: {'iterations': 1500, 'learning_rate': 0.1405787257021755, 'depth': 6, 'l2_leaf_reg': 0.43458580011494513}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:45:05,490] Trial 66 finished with value: 0.510655398584301 and parameters: {'iterations': 1200, 'learning_rate': 0.04871636153045471, 'depth': 7, 'l2_leaf_reg': 0.8333268129046999}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:45:15,552] Trial 67 finished with value: 0.5275679903236739 and parameters: {'iterations': 1100, 'learning_rate': 0.057122388885309475, 'depth': 5, 'l2_leaf_reg': 0.5491186976806525}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:45:26,650] Trial 68 finished with value: 0.5212035726221373 and parameters: {'iterations': 900, 'learning_rate': 0.16151692195302159, 'depth': 6, 'l2_leaf_reg': 0.24719016565604596}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:45:55,764] Trial 69 finished with value: 0.5272110092145438 and parameters: {'iterations': 1400, 'learning_rate': 0.04232955164201297, 'depth': 7, 'l2_leaf_reg': 0.6894377453185192}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:46:09,711] Trial 70 finished with value: 0.5417804449804159 and parameters: {'iterations': 1000, 'learning_rate': 0.02970166711510113, 'depth': 6, 'l2_leaf_reg': 0.1791969786207927}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:49:49,652] Trial 83 finished with value: 0.5591057208479107 and parameters: {'iterations': 600, 'learning_rate': 0.1338762783677888, 'depth': 6, 'l2_leaf_reg': 1.41272481709174}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:49:56,061] Trial 84 finished with value: 0.5127020660673415 and parameters: {'iterations': 500, 'learning_rate': 0.18057709935415434, 'depth': 6, 'l2_leaf_reg': 2.5105984778135446}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:50:06,439] Trial 85 finished with value: 0.49749208100594744 and parameters: {'iterations': 500, 'learning_rate': 0.11603219528329124, 'depth': 7, 'l2_leaf_reg': 1.0221277981481771}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:50:31,623] Trial 86 finished with value: 0.5292175576911741 and parameters: {'iterations': 700, 'learning_rate': 0.07293993840429276, 'depth': 8, 'l2_leaf_reg': 0.9024261736200623}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:50:40,139] Trial 87 finished with value: 0.5367064492543719 and parameters: {'iterations': 600, 'learning_rate': 0.09977491872040582, 'depth': 6, 'l2_leaf_reg': 0.6988129102822457}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:50:53,302] Trial 88 finished with value: 0.503679421744326 and parameters: {'iterations': 600, 'learning_rate': 0.11316465609330842, 'depth': 7, 'l2_leaf_reg': 0.3585246984815393}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:50:58,860] Trial 89 finished with value: 0.5109036481189287 and parameters: {'iterations': 700, 'learning_rate': 0.15199627868274618, 'depth': 5, 'l2_leaf_reg': 0.5700160355609256}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:51:17,064] Trial 90 finished with value: 0.5300884779360102 and parameters: {'iterations': 500, 'learning_rate': 0.08326813960235818, 'depth': 8, 'l2_leaf_reg': 1.2942534326057815}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:51:27,438] Trial 91 finished with value: 0.5736740608966496 and parameters: {'iterations': 800, 'learning_rate': 0.06992397074255706, 'depth': 6, 'l2_leaf_reg': 0.2680417609665877}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:51:37,460] Trial 92 finished with value: 0.5574487541167727 and parameters: {'iterations': 800, 'learning_rate': 0.06903913107516904, 'depth': 6, 'l2_leaf_reg': 0.27357860237324094}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:51:46,457] Trial 93 finished with value: 0.5466718712845777 and parameters: {'iterations': 800, 'learning_rate': 0.07510732188621363, 'depth': 6, 'l2_leaf_reg': 0.22379791874963534}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:51:57,233] Trial 94 finished with value: 0.5799402548975621 and parameters: {'iterations': 900, 'learning_rate': 0.05222106172028633, 'depth': 6, 'l2_leaf_reg': 0.38078401513945065}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:52:08,586] Trial 95 finished with value: 0.5830741900129831 and parameters: {'iterations': 900, 'learning_rate': 0.052081567325893995, 'depth': 6, 'l2_leaf_reg': 0.4336010762146534}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:52:18,725] Trial 96 finished with value: 0.5740392761274504 and parameters: {'iterations': 900, 'learning_rate': 0.05177013652990994, 'depth': 6, 'l2_leaf_reg': 0.39954623697168956}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:52:28,723] Trial 97 finished with value: 0.5739510665018066 and parameters: {'iterations': 900, 'learning_rate': 0.04943771136252493, 'depth': 6, 'l2_leaf_reg': 0.3830407547198655}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:52:39,020] Trial 98 finished with value: 0.5656764342486681 and parameters: {'iterations': 900, 'learning_rate': 0.05060816049593398, 'depth': 6, 'l2_leaf_reg': 0.3876963309160676}. Best is trial 26 with value: 0.5837218637328757.
# [I 2025-12-13 15:52:49,513] Trial 99 finished with value: 0.5714552369801907 and parameters: {'iterations': 900, 'learning_rate': 0.043808697475722136, 'depth': 6, 'l2_leaf_reg': 0.4706882025424657}. Best is trial 26 with value: 0.5837218637328757.

# %%
# Вывод лучших результатов
print(f"Лучшие параметры: {study.best_params}")
print(f"Лучший результат (R2): {study.best_value:.4f}")
# Out:
# Лучшие параметры: {'iterations': 900, 'learning_rate': 0.0454003744102823, 'depth': 6, 'l2_leaf_reg': 0.42244692292544583}
# Лучший результат (R2): 0.5837

# %%
# Обучение финальной модели на лучших параметрах
best_model = CatBoostRegressor(
    **study.best_params,
    random_seed=42,
    verbose=0
    # cat_features=cat_features
)
best_model.fit(X_train_scaled, y_train)

# %%
# Предсказание
y_pred = best_model.predict(X_test_scaled)

# %%
# Вычислим MSE, RMSE и MAE на тестовой выборке
mse = mean_squared_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)  
mape = mean_absolute_percentage_error(y_test, y_pred) 
 
# Рассчитаем Коэффициент детерминации на обучающей и тестовой выборках
r_cat_train = best_model.score(X_train_scaled, y_train)
r_cat_test = best_model.score(X_test_scaled, y_test)

print(f"MSE (Mean Squared Error):  {mse:.2f}")
print(f"RMSE (Root Mean Squared Error): {rmse:.2f}")
print(f"MAE (Mean Absolute Error): {mae:.2f}")
print(f"MAPE (Mean Absolute Percentage Error): {mape:.2f}")

print(f"Коэффициент детерминации на train r^2: {r_cat_train}")
print(f"Коэффициент детерминации на test r^2: {r_cat_test}")
# Out:
# MSE (Mean Squared Error):  1052316856371744997376.00
# RMSE (Root Mean Squared Error): 32439433662.93
# MAE (Mean Absolute Error): 15367945272.19
# MAPE (Mean Absolute Percentage Error): 0.61
# Коэффициент детерминации на train r^2: 0.9998987647804097
# Коэффициент детерминации на test r^2: 0.6742431443464872
